# %%
import pandas as pd
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12092\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# MODEL TRAINING

# %%
df=pd.read_csv(r'C:\Users\HP\Desktop\Satudents Marks Prediction\Data\Student_Marks.csv')

# %%
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
df2=df.fillna(df.mean())
df2.isnull().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64

# %%
df=df.copy()

# %%
# Assuming 'df' is your DataFrame containing the dataset

# Independent features (X)
x = df.drop(labels='Marks', axis='columns')

# Dependent variable (y)
y = df[['Marks']]  # Assuming 'Marks' is the target variable

print(x.shape, y.shape)
# Out:
# (100, 2) (100, 1)

# %%
# Train Test Split

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=30)

# %%
## Model Training
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([[1.79070625, 5.31219602]])

# %%
regression.intercept_
# Out:
# array([-6.9046092])

# %%
import numpy as np
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
# Training Multiple Models
models= {
    'LinearRegresssion':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'ElasticNet':ElasticNet()
}

trained_model_list=[]
model_list=[]
r2_list=[]


for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(x_train,y_train)
    
    #make predictions
    
    y_pred = model.predict(x_test)
    mae, rmse, r2_square = evaluate_model(y_test,y_pred)
    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    
    print('Model Trainig Performance')
    print("RMSE:",rmse)    
    print("MAE:",mae) 
    print("r2 score:",r2_square*100) 
    
    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegresssion
# Model Trainig Performance
# RMSE: 3.5255975372539003
# MAE: 3.037909712583393
# r2 score: 94.7669419316927
# ...
#
#
# Lasso
# Model Trainig Performance
# RMSE: 3.7781584303705493
# MAE: 3.2119476938141145
# r2 score: 93.9903328865683
# ...
#
#
# Ridge
# Model Trainig Performance
# RMSE: 3.5351437655285176
# MAE: 3.045267555802213
# r2 score: 94.73856455791501
# ...
#
#
# ElasticNet
# Model Trainig Performance
# RMSE: 4.200326474902165
# MAE: 3.5063994196006414
# r2 score: 92.57226876134979
# ...

# %%
model_list
# Out:
# ['LinearRegresssion', 'Lasso', 'Ridge', 'ElasticNet']

# %%
import  joblib
joblib.dump(regression, "students marks prediction.pkl")
# Out:
# ['students marks prediction.pkl']

# %%
model = joblib.load('students marks prediction.pkl')

# %%
model.predict([[1,15]])[0][0].round(2)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 74.57

# %%
pd.DataFrame(np.c_[x_test, y_test, y_pred], columns=["number_of_courses", "study_time", "actual_marks", "predicted_marks"])
# Out:
#     number_of_courses  study_time  actual_marks  predicted_marks
# 0                 4.0       4.733        22.073        25.377935
# 1                 8.0       2.730        19.564        21.650785
# 2                 3.0       4.083        17.171        20.786322
# 3                 4.0       0.771         7.892         6.361022
# 4                 4.0       4.410        20.348        23.827591
# 5                 4.0       6.954        39.952        36.038350
# 6                 6.0       6.126        35.939        35.007545
# 7                 5.0       1.803        11.253        12.786168
# 8                 7.0       7.957        54.321        45.267753
# 9                 7.0       6.376        40.024        37.679227
# 10                4.0       7.410        44.099        38.227071
# 11                7.0       6.533        41.358        38.432800
# 12                3.0       4.508        19.202        22.826248
# ...

# %%
regression.score(x_test,y_test) #94% accuraccy
# Out:
# 0.947669419316927
